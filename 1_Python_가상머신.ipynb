# %% [markdown]
# <a href="https://colab.research.google.com/github/leeyuuj/Test/blob/main/1_Python_%EA%B0%80%EC%83%81%EB%A8%B8%EC%8B%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 파이썬의 가상머신

# %% [markdown]
# ## 가상 머신이란?

# %% [markdown]
# 컴퓨터는 기계어만 이해하기 때문에 프로그램을 실행하기 위해 컴퓨터에 제출하기 전에 모든 프로그램을 기계어로 변환해야 한다. 이를 위해서는 컴파일러의 도움을 받아야 한다. 컴파일러는 일반적으로 프로그램 소스 코드를 기계어 코드로 변환한다.
#
# Python 컴파일러는 동일한 작업을 수행하지만 약간 다른 방식으로 수행한다. 프로그램 소스 코드를 바이트 코드라고 하는 다른 코드로 변환한다. 각 Python 프로그램 문은 바이트 코드 명령어 그룹으로 변환된다. 그렇다면 바이트 코드는 무엇인가?
#
# 바이트 코드는 모든 유형의 작업을 나타내는 Python 개발자가 만든 고정 명령어 집합을 나타낸다. 각 바이트 코드 명령어의 크기는 1바이트(또는 8비트)이므로 이를 바이트 코드 명령어라고 한다. 파이썬 조직에서는 때때로 기존 바이트 코드 명령어에 새로운 명령어가 추가될 수 있다고 말한다. .pyc 파일에서 바이트 코드 지침을 찾을 수 있다.
#
# Python 가상 머신(PVM)의 역할은 바이트 코드 명령어를 머신 코드로 변환하여 컴퓨터가 해당 머신 코드 명령어를 실행하고 최종 출력을 표시할 수 있도록 하는 것이다. 이 변환을 수행하기 위해 PVM에는 인터프리터가 장착되어 있다. 인터프리터는 바이트 코드를 기계어 코드로 변환하고 그 기계어 코드를 실행을 위해 컴퓨터 프로세서로 보낸다. 인터프리터가 주요 역할을 하기 때문에 종종 Python 가상 머신을 인터프리터라고도 한다.
#
# [출처](https://www.gkindex.com/python-tutorial/python-virtual-machine.jsp)

# %% [markdown]
# ## 가상머신을 이용한 파이썬 명령문의 수행 과정

# %% [markdown]
# 파이썬 가상머신은 파이썬 언어를 기계어로 변환해준다.

# %% [markdown]
# ![가상머신.PNG](data:image/png;base64,...)

# %% [markdown]
# **출처 : 도서-<한 권으로 배우는 파이썬 기초 & 알고리즘 사고법>**

# %% [markdown]
# 하나의 물리적인 머신에 여러 개의 가상 머신을 올릴 수 있듯이, 한 머신에 여러 개의 파이썬 가상환경을 만들 수 있다.
#
# 이러한 가상환경은 파이썬 개발 환경을 독립적으로 만들기 위한 것으로, 각 개발환경마다 다른 파이썬 버전을 사용할 수도 있고 다른 패키지를 설치할 수 있다. 가상환경은 그 안에 파이썬 개발환경과 관련된 모든 것을 가지고 있다(Self-contained 환경). 만약 프로젝트마다 서로 다른 버전의 파이썬을 사용한다거나 각 프로젝트에 필요한 패키지가 다를 경우 혹은 개발환경을 그대로 나중에 실제 서버에 옮기고 싶을 경우 가상환경을 사용하면 편리하다.

# %% [markdown]
# ------------------

# %% [markdown]
# ## 자바의 가상머신(JVM)과 유사
#
# * JVM 특징
#   * 자바로 작성한 소스 코드를 해석해 실행하는 별도의 프로그램 (자바 프로그램을 실행시키는 도구)
#   * 프로그램 실행과정
#     - 프로그램이 자신이 필요한 컴퓨터 자원을 운영체제에게 주문
#     - CPU, 메모리, 각종 입출력 장치 등과 같은 컴퓨터 자원을 프로그램이 할당받음
#   * 자원 요청 방식
#     - 프로그램이 운영체제에게 필요한 컴퓨터 자원을 요청하는 방식이 운영체제마다 다름 (운영체제에 대해 종속성을 가짐)
#     - 자바는 JVM을 매개해서 운영체제와 소통 (OS마다 버전이 다름) </br>
#       -> 자바가 운영체제로부터 독립적
#   * 메모리 상에만 존재하는 가상머신

# %% [markdown]
# ## 가상환경
# * 정의 : 독립적인 파이썬의 실행 환경

# %% [markdown]
# - 패키지가 시스템 전체에 설치되는 것이 아니라, 특정 응용 프로그램에 사용되도록 설치될 수 있도록 하는 반 격리 된 파이썬 환경입니다.
#
# - 현재 설치된 파이썬 환경과 다른 독립된 환경을 말한다. 파이썬을 사용하다보면 여러가지 패키지를 설치해야 하는데 이 때 패키지간에 dependency(의존성)가 있는 경우, 패키지 버전이 다르면 에러가 발생한다. 파이썬 가상환경을 이용하지 않으면 다수의 프로그램이 하나의 파이썬 개발환경을 이용한다.
#
# - 또다른 프로그램을 위해 패키지를 업그레이드하거나 설치하는 경우, 패키지간의 버전이 맞지 않게 될 수 있다. 이 경우 다른 프로그램이 동작하지 않게 된다. 장고 개발을 할 때도 가상환경을 사용하지 않으면 특정 패키지가 업데이트됨에 따라 관련 소스를 수정해야 문제가 발생한다.
#
# - 결국 독립된 환경에서 파이썬을 이용하기 위해 가상환경을 사용한다

# %% [markdown]
# ![가상환경.png](data:image/png;base64,...)

# %% [markdown]
# [이미지 출처](https://velog.io/@ssssujini99/Django-%EA%B0%80%EC%83%81%ED%99%98%EA%B2%BDVirtual-Environments%EC%9D%B4%EB%9E%80-Pycharm%EC%97%90%EC%84%9C-%EA%B0%80%EC%83%81%ED%99%98%EA%B2%BD-%EC%84%B8%ED%8C%85%ED%95%98%EA%B8%B0)
